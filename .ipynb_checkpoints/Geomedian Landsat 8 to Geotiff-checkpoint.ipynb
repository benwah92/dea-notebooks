# %% [markdown]
# ### Geomedian Sentinel 2 to Geotiff
# Created by Amos Bennett.<br>
# Last Updated 08 Jul 20.<br>
# **Having issues loading landsat data with the load_ard. Need to change back to dc.load function.

# %%
# %matplotlib inline

import datacube
import datacube_stats
from datacube_stats.statistics import GeoMedian
from datacube.helpers import write_geotiff
from odc.ui import with_ui_cbk
import sys

sys.path.append("../Scripts")
from dea_datahandling import load_ard
from dea_plotting import display_map
from dea_plotting import rgb
# Out:
# /g/data/v10/public/modules/dea/20200605/lib/python3.6/site-packages/datacube/storage/masking.py:4: DeprecationWarning: datacube.storage.masking has moved to datacube.utils.masking
#   category=DeprecationWarning)

# %%
print(datacube.__version__)
# Out:
# 1.8.0

# %%
# Temporary solution to account for Collection 3 data being in a different
# database on the NCI

try:
    dc_landsat = datacube.Datacube(app="beaudesert_ls", env="c3-samples")
except:
    dc_landsat = datacube.Datacube(app="beaudesert_ls")

# %%
# Set the central latitude and longitude

central_lat = -28.0
central_lon = 153.0

# Set the buffer to load around the central coordinates - max 0.1 deg
buffer = 0.275

# Compute the bounding box for the study area
study_area_lat = (central_lat - buffer, central_lat + buffer)
study_area_lon = (central_lon - buffer, central_lon + buffer)

# %%
display_map(x=study_area_lon, y=study_area_lat)
# Out:
# /g/data/v10/public/modules/dea-env/20200605/lib/python3.6/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /g/data/v10/public/modules/dea-env/20200605/lib/python3.6/site-packages/pyproj/crs/crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# ...

# %%
# Create a query object
query = {
    "x": (central_lon - buffer, central_lon + buffer),
    "y": (central_lat - buffer, central_lat + buffer),
    "time": ("2020-01", "2020-06"),
    "measurements": [
        "nbart_blue",
        "nbart_green",
        "nbart_red",
        "nbart_nir",
        "nbart_swir_1",
        "nbart_swir_2",
    ],
    "output_crs": "EPSG:3577",
    "resolution": (-30, 30),
    #"group_by": "solar_day",
}

# Load available landsat data
ds = load_ard(dc=dc_landsat, products=["ga_ls8c_ard_3"], **query)

# Print output data
print(ds)
# Out:
# Loading ga_ls8c_ard_3 data
#     No data for ga_ls8c_ard_3
# No data returned for query
# None

# %%
# Compute geomedian using all observations in the dataset
geomedian = GeoMedian().compute(ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-8194215c47dc> in <module>
#       1 # Compute geomedian using all observations in the dataset
# ----> 2 geomedian = GeoMedian().compute(ds)
#
# /g/data/v10/public/modules/dea/20191127/lib/python3.6/site-packages/datacube_stats/statistics/geomedian.py in compute(self, data)
#      42
#      43             data = data.reduce(apply_geomedian, dim='time', keep_attrs=True, f=nangeomedian,
# ---> 44                                eps=self.eps, maxiters=self.maxiters)
#      45
#      46             return data.transpose(*to).to_dataset(dim='variable')
#
# /g/data/v10/public/modules/dea-env/20191127/lib/python3.6/site-packages/xarray/core/dataarray.py in reduce(self, func, dim, axis, keep_attrs, keepdims, **kwargs)
#    2214         """
#    2215
# ...

# %%
# Plot the result
rgb(geomedian, size=20)

# %%
import datetime

write_geotiff(
    "{datetime.datetime.now():%Y%m%d}_Beaudesert_Landsat_Geomedian.tif", geomedian
)
